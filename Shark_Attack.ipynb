# %% [markdown]
# <a href="https://colab.research.google.com/github/rashmi-22-stack/Shark_Attack/blob/main/Shark_Attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import files
# files.upload()

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt


# # Replace 'FILE_PATH' with the actual file path of my CSV file
# file_path = '/content/shark attacks.csv'

# Replace 'ENCODING' with the appropriate encoding of your CSV file
# Common encodings are 'utf-8', 'ISO-8859-1', 'latin-1', etc.
encoding = ' Windows-1252'

# Use the pandas read_csv() function to read the data from the CSV file
# df = pd.read_csv(file_path, encoding=encoding)
github_link = "https://github.com/rashmi-22-stack/Shark_Attack/raw/main/shark%20attacks.csv"
df = pd.read_csv(github_link,  encoding=encoding)
df.head()
# Out:
#   Case Number       Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-18  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-18  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# 488276

# %%
df.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       Case Number       Date    Year        Type    Country             Area  \
# 0      2018.06.25  25-Jun-18  2018.0     Boating        USA       California
# 1      2018.06.18  18-Jun-18  2018.0  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-18  2018.0     Invalid        USA           Hawaii
# 3      2018.06.08  08-Jun-18  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-18  2018.0    Provoked     MEXICO           Colima
# ...           ...        ...     ...         ...        ...              ...
# 6307            0        NaN     NaN         NaN        NaN              NaN
# 6308            0        NaN     NaN         NaN        NaN              NaN
# 6309            0        NaN     NaN         NaN        NaN              NaN
# 8702          NaN        NaN     NaN         NaN        NaN              NaN
# 25722          xx        NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
##  to do:..
#drop rows or /and columns
# concatenate column Date  and Time
# change date in datetime
# fillna with mean ,median or mode (imputation)

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#subset the df by ignoring unwanted columns
df1 = df[['Case Number',
    'Date', 'Year', 'Type',
    #'Country', 'Area',
      'Location',
       'Activity',
    #'Name', 'Sex ',
    'Age',
    'Injury',
    'Fatal (Y/N)', 'Time',
       'Species ',
    # 'Investigator or Source', 'pdf', 'href formula', 'href',
    #    'Case Number.1', 'Case Number.2', 'original order',
    'Unnamed: 22',
       'Unnamed: 23']].copy()

# %%
df1
# Out:
#       Case Number       Date    Year        Type  \
# 0      2018.06.25  25-Jun-18  2018.0     Boating
# 1      2018.06.18  18-Jun-18  2018.0  Unprovoked
# 2      2018.06.09  09-Jun-18  2018.0     Invalid
# 3      2018.06.08  08-Jun-18  2018.0  Unprovoked
# 4      2018.06.04  04-Jun-18  2018.0    Provoked
# ...           ...        ...     ...         ...
# 25718         NaN        NaN     NaN         NaN
# 25719         NaN        NaN     NaN         NaN
# 25720         NaN        NaN     NaN         NaN
# 25721         NaN        NaN     NaN         NaN
# 25722          xx        NaN     NaN         NaN
#
#                              Location     Activity  Age  \
# 0         Oceanside, San Diego County     Paddling   57
# 1      St. Simon Island, Glynn County     Standing   11
# 2                        Habush, Oahu      Surfing   48
# 3                  Arrawarra Headland      Surfing  NaN
# 4                            La Ticla  Free diving  NaN
# ...

# %%
#drop not needed columns
df1 = df1.drop(columns=['Unnamed: 22','Unnamed: 23'])

df1
# Out:
#       Case Number       Date    Year        Type  \
# 0      2018.06.25  25-Jun-18  2018.0     Boating
# 1      2018.06.18  18-Jun-18  2018.0  Unprovoked
# 2      2018.06.09  09-Jun-18  2018.0     Invalid
# 3      2018.06.08  08-Jun-18  2018.0  Unprovoked
# 4      2018.06.04  04-Jun-18  2018.0    Provoked
# ...           ...        ...     ...         ...
# 25718         NaN        NaN     NaN         NaN
# 25719         NaN        NaN     NaN         NaN
# 25720         NaN        NaN     NaN         NaN
# 25721         NaN        NaN     NaN         NaN
# 25722          xx        NaN     NaN         NaN
#
#                              Location     Activity  Age  \
# 0         Oceanside, San Diego County     Paddling   57
# 1      St. Simon Island, Glynn County     Standing   11
# 2                        Habush, Oahu      Surfing   48
# 3                  Arrawarra Headland      Surfing  NaN
# 4                            La Ticla  Free diving  NaN
# ...

# %%
# concatenate Date and Time columns
df1['Date&Time']= df1['Date']+df1['Time']
df1
# Out:
#       Case Number       Date    Year        Type  \
# 0      2018.06.25  25-Jun-18  2018.0     Boating
# 1      2018.06.18  18-Jun-18  2018.0  Unprovoked
# 2      2018.06.09  09-Jun-18  2018.0     Invalid
# 3      2018.06.08  08-Jun-18  2018.0  Unprovoked
# 4      2018.06.04  04-Jun-18  2018.0    Provoked
# ...           ...        ...     ...         ...
# 25718         NaN        NaN     NaN         NaN
# 25719         NaN        NaN     NaN         NaN
# 25720         NaN        NaN     NaN         NaN
# 25721         NaN        NaN     NaN         NaN
# 25722          xx        NaN     NaN         NaN
#
#                              Location     Activity  Age  \
# 0         Oceanside, San Diego County     Paddling   57
# 1      St. Simon Island, Glynn County     Standing   11
# 2                        Habush, Oahu      Surfing   48
# 3                  Arrawarra Headland      Surfing  NaN
# 4                            La Ticla  Free diving  NaN
# ...

# %%
# drop individual columns
df2=df1.drop(columns=['Date', 'Time', 'Year'])
df2
# Out:
#       Case Number        Type                        Location     Activity  \
# 0      2018.06.25     Boating     Oceanside, San Diego County     Paddling
# 1      2018.06.18  Unprovoked  St. Simon Island, Glynn County     Standing
# 2      2018.06.09     Invalid                    Habush, Oahu      Surfing
# 3      2018.06.08  Unprovoked              Arrawarra Headland      Surfing
# 4      2018.06.04    Provoked                        La Ticla  Free diving
# ...           ...         ...                             ...          ...
# 25718         NaN         NaN                             NaN          NaN
# 25719         NaN         NaN                             NaN          NaN
# 25720         NaN         NaN                             NaN          NaN
# 25721         NaN         NaN                             NaN          NaN
# 25722          xx         NaN                             NaN          NaN
#
# ...

# %%
# Convert 'datetime_str' column to pandas datetime objects
df2['Date&Time'] = pd.to_datetime(df2['Date&Time'],  format='%d-%b-%Yh%M',errors='coerce')
df2
# Out:
#       Case Number        Type                        Location     Activity  \
# 0      2018.06.25     Boating     Oceanside, San Diego County     Paddling
# 1      2018.06.18  Unprovoked  St. Simon Island, Glynn County     Standing
# 2      2018.06.09     Invalid                    Habush, Oahu      Surfing
# 3      2018.06.08  Unprovoked              Arrawarra Headland      Surfing
# 4      2018.06.04    Provoked                        La Ticla  Free diving
# ...           ...         ...                             ...          ...
# 25718         NaN         NaN                             NaN          NaN
# 25719         NaN         NaN                             NaN          NaN
# 25720         NaN         NaN                             NaN          NaN
# 25721         NaN         NaN                             NaN          NaN
# 25722          xx         NaN                             NaN          NaN
#
# ...

# %%
# Convert 'Age' to numeric
df2['Age'] = pd.to_numeric(df2['Age'], errors='coerce')

df2
# Out:
#       Case Number        Type                        Location     Activity  \
# 0      2018.06.25     Boating     Oceanside, San Diego County     Paddling
# 1      2018.06.18  Unprovoked  St. Simon Island, Glynn County     Standing
# 2      2018.06.09     Invalid                    Habush, Oahu      Surfing
# 3      2018.06.08  Unprovoked              Arrawarra Headland      Surfing
# 4      2018.06.04    Provoked                        La Ticla  Free diving
# ...           ...         ...                             ...          ...
# 25718         NaN         NaN                             NaN          NaN
# 25719         NaN         NaN                             NaN          NaN
# 25720         NaN         NaN                             NaN          NaN
# 25721         NaN         NaN                             NaN          NaN
# 25722          xx         NaN                             NaN          NaN
#
# ...

# %%
df2.dtypes
# Out:
# Case Number            object
# Type                   object
# Location               object
# Activity               object
# Age                   float64
# Injury                 object
# Fatal (Y/N)            object
# Species                object
# Date&Time      datetime64[ns]
# dtype: object

# %%
# drop rows with all NaN values
df3= df2.dropna(how='all')# letting original df not modify (not using 'inplace =True')

# %%
df3
# Out:
#       Case Number        Type                        Location     Activity  \
# 0      2018.06.25     Boating     Oceanside, San Diego County     Paddling
# 1      2018.06.18  Unprovoked  St. Simon Island, Glynn County     Standing
# 2      2018.06.09     Invalid                    Habush, Oahu      Surfing
# 3      2018.06.08  Unprovoked              Arrawarra Headland      Surfing
# 4      2018.06.04    Provoked                        La Ticla  Free diving
# ...           ...         ...                             ...          ...
# 8698            0         NaN                             NaN          NaN
# 8699            0         NaN                             NaN          NaN
# 8700            0         NaN                             NaN          NaN
# 8701            0         NaN                             NaN          NaN
# 25722          xx         NaN                             NaN          NaN
#
# ...

# %%
df3.nunique()
# Out:
# Case Number    6287
# Type              8
# Location       4108
# Activity       1532
# Age              80
# Injury         3737
# Fatal (Y/N)       8
# Species        1549
# Date&Time       124
# dtype: int64

# %%
df3.shape
# Out:
# (8703, 9)

# %%
df3.isnull().sum().sum()
# Out:
# 32813

# %%
df3.isnull().sum()
# Out:
# Case Number       1
# Type           2405
# Location       2941
# Activity       2945
# Age            5334
# Injury         2429
# Fatal (Y/N)    2940
# Species        5239
# Date&Time      8579
# dtype: int64

# %%
df3.columns
# Out:
# Index(['Case Number', 'Type', 'Location', 'Activity', 'Age', 'Injury',
#        'Fatal (Y/N)', 'Species ', 'Date&Time'],
#       dtype='object')

# %%
# Drop duplicate rows
df3.drop_duplicates(inplace=True)
df3
# Out:
# <ipython-input-70-4bf6052401a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop_duplicates(inplace=True)
#       Case Number        Type                             Location  \
# 0      2018.06.25     Boating          Oceanside, San Diego County
# 1      2018.06.18  Unprovoked       St. Simon Island, Glynn County
# 2      2018.06.09     Invalid                         Habush, Oahu
# 3      2018.06.08  Unprovoked                   Arrawarra Headland
# 4      2018.06.04    Provoked                             La Ticla
# ...           ...         ...                                  ...
# 6299      ND.0003  Unprovoked                       Ocracoke Inlet
# 6300      ND.0002  Unprovoked                 Panama Bay 8ºN, 79ºW
# ...

# %%
###   To Do:  ....
# 1.What are the most dangerous types of sharks to humans? #most attacks + type of shark
# 2.Are children more likely to be attacked by sharks? # find number of childern attacked by shark comparison to adults
# 3.Are shark attacks where sharks were provoked more or less dangerous? # count shark attacks where provoked comparison to less provoked
# 4.Are certain activities more likely to result in a shark attack? #count  most attacks on particular activity
# answer and assumptions!!

# %%
#Q.1. What are the most dangerous types of sharks to humans?

# Grouping by species and counting fatal attacks
most_dangerous_sharks = df3[df3['Fatal (Y/N)'] == 'Y'].groupby('Species ')['Case Number'].count().sort_values(ascending=False)
# most_dangerous_sharks.head()
display(most_dangerous_sharks)

# Plotting the data on a horizontal bar chart
plt.figure(figsize=(10, 6))
most_dangerous_sharks.head(10).sort_values().plot(kind='barh', color='red')
plt.xlabel('Number of Fatal Attacks')
plt.ylabel('Shark Species')
plt.title('Most Dangerous Shark Species (Fatal Attacks)')
plt.show()
# Out:
# Species
# White shark              44
# Tiger shark              25
# Bull shark               15
# 3.7 m [12'] shark         9
# 3 m [10'] shark           8
#                          ..
# Blue pointers             1
# Blue shark, 3 m [10']     1
# Blue shark?               1
# Bronze whaler shark       1
# small sharks'             1
# Name: Case Number, Length: 274, dtype: int64

# %% [markdown]
# **Q.1 .What are the most dangerous types of sharks to humans?**
#
# **Answer**:Very obvious from chart shows that white shark is the most dangerous as it holds most number of fatal attacks. Even though The given dataset lacks detailed information on the outcomes (fatal or non-fatal) for each shark attack, which is essential in determining the danger level of each shark species to humans.
#
# **Assumptions**: Assuming that the dataset includes information about all shark attacks on humans.

# %%
# # df3.head(20)
# df3.describe()
# # df3.info()

# %%
## # Q.2.Are children more likely to be attacked by sharks?

# Function to categorize age into groups
def categorize_age(age):
    if age < 12:
        return '<12'
    elif 12 <= age < 18:
        return '12-18'
    else:
        return 'Adult'

# # Convert 'Age' to numeric  and drop rows with non-numeric values
# df3['Age'] = pd.to_numeric(df3['Age'], errors='coerce')
# Impute missing values in 'Age' column with the median age
median_age = df3['Age'].median()
df3['Age'].fillna(median_age, inplace=True)
# Categorize ages into groups using the 'categorize_age' function
df3['Age Group'] = df3['Age'].apply(categorize_age)

# Count the occurrences of each age group
age_group_counts = df3['Age Group'].value_counts()
display(age_group_counts)

# Plotting the data on a bar chart
plt.bar(age_group_counts.index, age_group_counts.values)
plt.xlabel('Age group')
plt.ylabel('Number of Attacks')
plt.title('Shark Attacks by Age Group')

plt.show()
# Out:
# <ipython-input-35-4d41a870e003>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Age'].fillna(median_age, inplace=True)
# <ipython-input-35-4d41a870e003>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Age Group'] = df3['Age'].apply(categorize_age)
# Adult    7798
# 12-18     699
# <12       206
# Name: Age Group, dtype: int64

# %% [markdown]
# *** Q.2 .Are children more likely to be attacked by sharks?***
#
# **Answer**: Based on the provided dataset, i analyzed the number of shark attacks involving children (age < 18) and adults (age >= 18). The analysis showed the number of attacks for each age group. And results shows adults are more likely to be attacked by sharks than the children under 18 with great difference.
# **Assumptions**: The dataset includes information on the age of the victims, (with additional  factors, such as the popularity of certain activities among children, which may influence the likelihood of shark attacks on this age group.)

# %%
# # 3. Are shark attacks where sharks were provoked more or less dangerous?# Grouping by provoked attacks and counting fatal attacks

#  count all occurrences of provoked and unprovoked in the 'Type' column
Provoked_count = df3[df3['Type'].str.contains('Provoked', na=False)]['Type'].count()
Unprovoked_count = df3[df3['Type'].str.contains('Unprovoked', na=False)]['Type'].count()
print("Number of provoked attacks:", Provoked_count)
print("Number of Unprovoked attacks:", Unprovoked_count)
#count other type also
Questionable_count = df3[df3['Type'].str.contains('Questionable', na=False)]['Type'].count()
Invalid_count = df3[df3['Type'].str.contains('Invalid', na=False)]['Type'].count()
print("Number of Invlaid attacks:", Invalid_count)
print("Number of Questionable attacks:", Questionable_count)

# Plotting the data on a bar chart
types = ['Provoked', 'Unprovoked', 'Questionable', 'Invalid']
counts = [Provoked_count, Unprovoked_count, Questionable_count, Invalid_count]

plt.bar(types, counts)
plt.xlabel('Type of Shark Attack')
plt.ylabel('Number of Occurrences')
plt.title('Occurrences of Different Types of Shark Attacks')
plt.show()
# Out:
# Number of provoked attacks: 574
# Number of Unprovoked attacks: 4595
# Number of Invlaid attacks: 547
# Number of Questionable attacks: 2

# %%
df3

# %%
# Function to categorize attack types as provoked or unprovoked
def categorize_attack_type(attack_type):
    if pd.notna(attack_type) and 'Provoked' in attack_type:
        return 'Provoked'
    else:
        return 'Unprovoked'

# Apply the 'categorize_attack_type' function to create a new column 'Attack Type'
df3['Attack Type'] = df3['Type'].apply(categorize_attack_type)

# Count the number of fatal and non-fatal attacks for each attack type
attack_counts = df3.groupby(['Attack Type', 'Fatal (Y/N)'])['Case Number'].count().unstack().fillna(0)

# Plotting the data on a grouped bar chart
plt.figure(figsize=(10, 6))
bar_width = 0.35
bar_positions = [0, 1]
# Plotting the grouped bar chart
attack_counts.plot(kind='bar', stacked=True, width=bar_width, color=['skyblue', 'lightblue', 'salmon', 'lightcoral'])


plt.xlabel('Attack Type')
plt.ylabel('Number of Attacks')
plt.title('Shark Attacks: Provoked vs. Unprovoked')
# Setting y-axis ticks with rotation and alignment
plt.xticks([pos + bar_width / 2 for pos in bar_positions], ['Provoked', 'Unprovoked'], rotation=0, ha='right')

# Placing the legend outside the chart
plt.legend(title='Fatal (Y/N)', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-71-42a10a0edd63>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Attack Type'] = df3['Type'].apply(categorize_attack_type)

# %% [markdown]
# ### **#Q.3 .Are shark attacks where sharks were provoked more or less dangerous?**
#
# **Answer**: The dataset indicates whether an attack was "Provoked" or "Unprovoked," but it does not provide information about the danger level of each attack type. We can compare the number of fatal and non-fatal attacks in each category, but it would be an indirect measure of danger, not a direct assessment.Based on this information, we can conclude that 'Provoked' shark attacks are generally less dangerous than 'Unprovoked' attacks because they result in fewer fatal outcomes.
#
# **Assumptions**: Assuming that the categorization of "Provoked" and "Unprovoked" attacks in the dataset is accurate. However, the dataset does not contain detailed information on the specific circumstances or reasons for each attack, which could influence the danger level of provoked attacks.

# %%
## 4. Are certain activities more likely to result in a shark attack?

# Impute missing values in 'Activity' column with the most frequent activity (mode)
most_frequent_activity = df3['Activity'].mode().iloc[0]
df3['Activity'].fillna(most_frequent_activity, inplace=True)
# Count the occurrences of each activity
activity_counts = df3['Activity'].value_counts()
## (visualisation is not possible for each activity due to too many sort of activities ).

# Select the top 10 activities with the highest number of shark attacks
top_10 = 10
top_activities = activity_counts.head(top_10)

# Plotting the data on a bar chart
plt.figure(figsize=(12, 6))
top_activities.plot(kind='bar', color='skyblue')
plt.xlabel('Activity')
plt.ylabel('Number of Attacks')
plt.title('Top {} Activities Most Likely to Result in Shark Attacks'.format(top_10))
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-50-d5e9b06e5adc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Activity'].fillna(most_frequent_activity, inplace=True)

# %%
# Count the occurrences of each activity in the particular most happened location
most_happened_location = df3['Location'].value_counts().idxmax()
activities_in_most_happened_location = df3[df3['Location'] == most_happened_location]['Activity'].value_counts()

# Select the top 10 activities with the highest number of shark attacks in the most happened location
top_10 = 10
top_activities = activities_in_most_happened_location.head(top_10)

# Plotting the data on a bar chart
plt.figure(figsize=(12, 6))
top_activities.plot(kind='bar', color='skyblue')
plt.xlabel('Activity')
plt.ylabel('Number of Attacks')
plt.title('Top {} Activities Most Likely to Result in Shark Attacks in {}'.format(top_10, most_happened_location))
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ***# Q.4 .Are certain activities more likely to result in a shark attack?***
#
# **Answer**: Based on the provided dataset, after analyzing the occurrences of different activities associated with shark attacks. The dataset shows the number of attacks related to each activity. With the top 10 activities most likely to result in shark attacks And Surfing is the most relevant activity to attract sharks easily which is mostly took place in New Symrna Beach comparing to other locations.
#
# **Assumptions**: The dataset contains information on activities associated with shark attacks. However, it may not cover all activities or may lack specific details on the frequencies, or other contextual factors that could affect the likelihood of shark attacks during certain activities.
